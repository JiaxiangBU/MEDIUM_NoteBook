# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tqdm

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_log_error, mean_squared_error
import re
import os
import random
import datetime

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import tensorflow.keras.backend as K
print('tf.__version__: ',tf.__version__)
# Out:
# tf.__version__:  2.0.0

# %%
### READ DATA AND CREATE FEATURES FOR year, month, day, hour ###
df = pd.read_csv('nyc_taxi.csv')

date = pd.DataFrame(np.vstack(df.timestamp.apply(lambda x: re.sub(r':|-' ,' ', x).split()))[:,:4].astype(int))

df = pd.concat([df, date], axis=1)
df.columns = ['timestamp','value','yr','mt','d','H']
df.head()

print(df.shape)
df.head()
# Out:
# (10320, 6)
#              timestamp  value    yr  mt  d  H
# 0  2014-07-01 00:00:00  10844  2014   7  1  0
# 1  2014-07-01 00:30:00   8127  2014   7  1  0
# 2  2014-07-01 01:00:00   6210  2014   7  1  1
# 3  2014-07-01 01:30:00   4656  2014   7  1  1
# 4  2014-07-01 02:00:00   3820  2014   7  1  2

# %% [markdown]
# 生成朴素的时间变量。

# %%
### PLOT SAMPLE OF DATA ###
df.iloc[8400:8400+7*48,:].plot(y='value',x='timestamp',figsize=(8,6))
plt.xticks(rotation=70)
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300., 350., 400.]),
#  <a list of 10 Text xticklabel objects>)

# %% [markdown]
# 单时间序列呈现周期性。

# %% [markdown]
# > `df.value.autocorr`: This method computes the Pearson correlation between
# the Series and its shifted self.
#
# 查看时间自相关性。

# %%
### WEEKLY AUTOCORR PLOT (10 WEEKS DEPTH) ###
timeLags = np.arange(1,10*48*7)
autoCorr = [df.value.autocorr(lag=dt) for dt in timeLags]

plt.figure(figsize=(19,8))
plt.plot(1.0/(48*7)*timeLags, autoCorr);
plt.xlabel('time lag [weeks]'); plt.ylabel('correlation coeff', fontsize=12);

# %%
print('数据集长度',df.shape)
print('考虑滞后次数',len(timeLags),'产生自相关系数',len(autoCorr))
# Out:
# 数据集长度 (10320, 9)
# 考虑滞后次数 3359 产生自相关系数 3359

# %%
### CREATE WEEKDAY FEATURE AND COMPUTE THE MEAN FOR WEEKDAYS AT EVERY HOURS ###
weekday = df[['yr', 'mt', 'd']].apply(lambda x: datetime.datetime(x['yr'], x['mt'], x['d']).weekday(),axis=1).values

df['weekday'] = weekday
df['weekday_hour'] = df.weekday.astype(str) +' '+ df.H.astype(str)
# 周几的第几个小时，交叉项特征
df['m_weekday'] = df.weekday_hour.replace(df[:5000].groupby('weekday_hour')['value'].mean().to_dict())
# target encoding，但是这个处理方式有信息漏出，直接用测试集的Y数据

# %%
### CREATE GENERATOR FOR LSTM ###
sequence_length = 48
# 按照48的长度，把时间序列滚动的平移，产生特征。

def gen_index(id_df, seq_length, seq_cols):

    data_matrix =  id_df[seq_cols]
    num_elements = data_matrix.shape[0]

    for start, stop in zip(range(0, num_elements-seq_length, 1), range(seq_length, num_elements, 1)):
        
        yield data_matrix[stop-sequence_length:stop].values.reshape((-1,len(seq_cols)))

# %%
print('因此，长度上原始时间序列短',df.shape[0]-cnt.shape[0],'个单位。')
# Out:
# 因此，长度上原始时间序列短 48 个单位。

# %%
### CREATE AND STANDARDIZE DATA FOR LSTM ### 
cnt, mean = [], []
for sequence in gen_index(df, sequence_length, ['value']):
    cnt.append(sequence)
    
for sequence in gen_index(df, sequence_length, ['m_weekday']):
    mean.append(sequence)

cnt, mean = np.log(cnt), np.log(mean)
cnt = cnt - mean
cnt.shape
# Out:
# (10272, 48, 1)

# %% [markdown]
# 生成的 LTSM 的输入是时间序列相对于一周均值的差异。

# %%
### CREATE AND STANDARDIZE LABEL FOR LSTM ###
init = df.m_weekday[sequence_length:].apply(np.log).values
label = df.value[sequence_length:].apply(np.log).values - init
label.shape
# Out:
# (10272,)

# %%
print('目标的长度也是少',df.shape[0]-label.shape[0],'个单位。定义是当前时间点y和周均的差异。')
# Out:
# 目标的长度也是少 48 个单位。定义是当前时间点y和周均的差异。

# %% [markdown]
# 因此整个时间序列模型的训练，就是把滞后48期作为特征进行监督训练。

# %%
### DEFINE QUANTILE LOSS ###
def q_loss(q,y,f):
    e = (y-f)
    return K.mean(K.maximum(q*e, (q-1)*e), axis=-1)

# %%
### TRAIN TEST SPLIT ###
X_train, X_test = cnt[:5000], cnt[5000:]
y_train, y_test = label[:5000], label[5000:]
# 按照时间进行训练和测试集切分。

# %%
### SET SEED ###
tf.random.set_seed(33)
os.environ['PYTHONHASHSEED'] = str(33)
np.random.seed(33)
random.seed(33)

# session_conf = tf.compat.v1.ConfigProto(
#     intra_op_parallelism_threads=1, 
#     inter_op_parallelism_threads=1
# )
# sess = tf.compat.v1.Session(
#     graph=tf.compat.v1.get_default_graph(), 
#     config=session_conf
# )
# tf.compat.v1.keras.backend.set_session(sess)

### CREATE MODEL ###
losses = [lambda y,f: q_loss(0.1,y,f), lambda y,f: q_loss(0.5,y,f), lambda y,f: q_loss(0.9,y,f)]

inputs = Input(shape=(X_train.shape[1], X_train.shape[2]))
lstm = Bidirectional(LSTM(64, return_sequences=True, dropout=0.3))(inputs, training = True)
lstm = Bidirectional(LSTM(16, return_sequences=False, dropout=0.3))(lstm, training = True)
dense = Dense(50)(lstm)
out10 = Dense(1)(dense)
out50 = Dense(1)(dense)
out90 = Dense(1)(dense)
# 构建三个输出，为了之后进行 BOOTSTRAPPING，三者目前为止一致。

model = Model(inputs, [out10,out50,out90])
model.compile(loss=losses, optimizer='adam', loss_weights = [0.3,0.3,0.3])

# %%
history = model.fit(X_train, [y_train,y_train,y_train], epochs=50, batch_size=128, verbose=2, shuffle=True)
# Out:
# Train on 5000 samples
# Epoch 1/50
# 5000/5000 - 15s - loss: 0.0288 - dense_1_loss: 0.0296 - dense_2_loss: 0.0450 - dense_3_loss: 0.0245
# Epoch 2/50
# 5000/5000 - 6s - loss: 0.0257 - dense_1_loss: 0.0236 - dense_2_loss: 0.0413 - dense_3_loss: 0.0215
# Epoch 3/50
# 5000/5000 - 7s - loss: 0.0252 - dense_1_loss: 0.0222 - dense_2_loss: 0.0404 - dense_3_loss: 0.0212
# Epoch 4/50
# 5000/5000 - 6s - loss: 0.0248 - dense_1_loss: 0.0217 - dense_2_loss: 0.0396 - dense_3_loss: 0.0206
# Epoch 5/50
# 5000/5000 - 7s - loss: 0.0239 - dense_1_loss: 0.0205 - dense_2_loss: 0.0388 - dense_3_loss: 0.0204
# Epoch 6/50
# 5000/5000 - 8s - loss: 0.0238 - dense_1_loss: 0.0205 - dense_2_loss: 0.0383 - dense_3_loss: 0.0197
# Epoch 7/50
# 5000/5000 - 7s - loss: 0.0230 - dense_1_loss: 0.0197 - dense_2_loss: 0.0370 - dense_3_loss: 0.0191
# Epoch 8/50
# 5000/5000 - 6s - loss: 0.0225 - dense_1_loss: 0.0199 - dense_2_loss: 0.0369 - dense_3_loss: 0.0191
# Epoch 9/50
# 5000/5000 - 6s - loss: 0.0218 - dense_1_loss: 0.0184 - dense_2_loss: 0.0355 - dense_3_loss: 0.0184
# Epoch 10/50
# 5000/5000 - 8s - loss: 0.0211 - dense_1_loss: 0.0185 - dense_2_loss: 0.0353 - dense_3_loss: 0.0181
# Epoch 11/50
# 5000/5000 - 7s - loss: 0.0203 - dense_1_loss: 0.0175 - dense_2_loss: 0.0338 - dense_3_loss: 0.0166
# Epoch 12/50
# 5000/5000 - 8s - loss: 0.0202 - dense_1_loss: 0.0174 - dense_2_loss: 0.0334 - dense_3_loss: 0.0166
# Epoch 13/50
# 5000/5000 - 6s - loss: 0.0199 - dense_1_loss: 0.0169 - dense_2_loss: 0.0328 - dense_3_loss: 0.0164
# Epoch 14/50
# 5000/5000 - 6s - loss: 0.0197 - dense_1_loss: 0.0166 - dense_2_loss: 0.0326 - dense_3_loss: 0.0164
# Epoch 15/50
# 5000/5000 - 8s - loss: 0.0195 - dense_1_loss: 0.0163 - dense_2_loss: 0.0319 - dense_3_loss: 0.0162
# Epoch 16/50
# 5000/5000 - 8s - loss: 0.0192 - dense_1_loss: 0.0165 - dense_2_loss: 0.0315 - dense_3_loss: 0.0159
# Epoch 17/50
# 5000/5000 - 9s - loss: 0.0192 - dense_1_loss: 0.0164 - dense_2_loss: 0.0317 - dense_3_loss: 0.0155
# Epoch 18/50
# 5000/5000 - 7s - loss: 0.0188 - dense_1_loss: 0.0162 - dense_2_loss: 0.0309 - dense_3_loss: 0.0153
# Epoch 19/50
# 5000/5000 - 6s - loss: 0.0189 - dense_1_loss: 0.0161 - dense_2_loss: 0.0310 - dense_3_loss: 0.0152
# Epoch 20/50
# 5000/5000 - 6s - loss: 0.0188 - dense_1_loss: 0.0160 - dense_2_loss: 0.0309 - dense_3_loss: 0.0150
# Epoch 21/50
# 5000/5000 - 6s - loss: 0.0188 - dense_1_loss: 0.0160 - dense_2_loss: 0.0317 - dense_3_loss: 0.0153
# Epoch 22/50
# 5000/5000 - 6s - loss: 0.0186 - dense_1_loss: 0.0160 - dense_2_loss: 0.0308 - dense_3_loss: 0.0155
# Epoch 23/50
# 5000/5000 - 6s - loss: 0.0179 - dense_1_loss: 0.0152 - dense_2_loss: 0.0300 - dense_3_loss: 0.0143
# Epoch 24/50
# 5000/5000 - 6s - loss: 0.0180 - dense_1_loss: 0.0151 - dense_2_loss: 0.0307 - dense_3_loss: 0.0149
# Epoch 25/50
# 5000/5000 - 7s - loss: 0.0180 - dense_1_loss: 0.0153 - dense_2_loss: 0.0304 - dense_3_loss: 0.0144
# Epoch 26/50
# 5000/5000 - 8s - loss: 0.0176 - dense_1_loss: 0.0148 - dense_2_loss: 0.0297 - dense_3_loss: 0.0139
# Epoch 27/50
# 5000/5000 - 7s - loss: 0.0174 - dense_1_loss: 0.0146 - dense_2_loss: 0.0294 - dense_3_loss: 0.0141
# Epoch 28/50
# 5000/5000 - 8s - loss: 0.0174 - dense_1_loss: 0.0144 - dense_2_loss: 0.0294 - dense_3_loss: 0.0139
# Epoch 29/50
# 5000/5000 - 6s - loss: 0.0174 - dense_1_loss: 0.0145 - dense_2_loss: 0.0293 - dense_3_loss: 0.0138
# Epoch 30/50
# 5000/5000 - 7s - loss: 0.0173 - dense_1_loss: 0.0144 - dense_2_loss: 0.0288 - dense_3_loss: 0.0137
# Epoch 31/50
# 5000/5000 - 7s - loss: 0.0169 - dense_1_loss: 0.0138 - dense_2_loss: 0.0286 - dense_3_loss: 0.0135
# Epoch 32/50
# 5000/5000 - 7s - loss: 0.0172 - dense_1_loss: 0.0144 - dense_2_loss: 0.0288 - dense_3_loss: 0.0135
# Epoch 33/50
# 5000/5000 - 7s - loss: 0.0172 - dense_1_loss: 0.0143 - dense_2_loss: 0.0289 - dense_3_loss: 0.0135
# Epoch 34/50
# 5000/5000 - 6s - loss: 0.0171 - dense_1_loss: 0.0144 - dense_2_loss: 0.0289 - dense_3_loss: 0.0135
# Epoch 35/50
# 5000/5000 - 7s - loss: 0.0170 - dense_1_loss: 0.0144 - dense_2_loss: 0.0293 - dense_3_loss: 0.0136
# Epoch 36/50
# 5000/5000 - 6s - loss: 0.0170 - dense_1_loss: 0.0141 - dense_2_loss: 0.0289 - dense_3_loss: 0.0132
# Epoch 37/50
# 5000/5000 - 7s - loss: 0.0168 - dense_1_loss: 0.0139 - dense_2_loss: 0.0286 - dense_3_loss: 0.0134
# Epoch 38/50
# 5000/5000 - 7s - loss: 0.0170 - dense_1_loss: 0.0141 - dense_2_loss: 0.0287 - dense_3_loss: 0.0135
# Epoch 39/50
# 5000/5000 - 6s - loss: 0.0171 - dense_1_loss: 0.0145 - dense_2_loss: 0.0293 - dense_3_loss: 0.0134
# Epoch 40/50
# 5000/5000 - 6s - loss: 0.0171 - dense_1_loss: 0.0142 - dense_2_loss: 0.0289 - dense_3_loss: 0.0136
# Epoch 41/50
# 5000/5000 - 7s - loss: 0.0175 - dense_1_loss: 0.0145 - dense_2_loss: 0.0294 - dense_3_loss: 0.0136
# Epoch 42/50
# 5000/5000 - 7s - loss: 0.0171 - dense_1_loss: 0.0142 - dense_2_loss: 0.0293 - dense_3_loss: 0.0133
# Epoch 43/50
# 5000/5000 - 6s - loss: 0.0167 - dense_1_loss: 0.0139 - dense_2_loss: 0.0285 - dense_3_loss: 0.0132
# Epoch 44/50
# 5000/5000 - 7s - loss: 0.0170 - dense_1_loss: 0.0142 - dense_2_loss: 0.0288 - dense_3_loss: 0.0135
# Epoch 45/50
# 5000/5000 - 6s - loss: 0.0170 - dense_1_loss: 0.0140 - dense_2_loss: 0.0289 - dense_3_loss: 0.0131
# Epoch 46/50
# 5000/5000 - 7s - loss: 0.0167 - dense_1_loss: 0.0137 - dense_2_loss: 0.0281 - dense_3_loss: 0.0132
# Epoch 47/50
# 5000/5000 - 6s - loss: 0.0169 - dense_1_loss: 0.0142 - dense_2_loss: 0.0289 - dense_3_loss: 0.0132
# Epoch 48/50
# 5000/5000 - 6s - loss: 0.0168 - dense_1_loss: 0.0140 - dense_2_loss: 0.0289 - dense_3_loss: 0.0132
# Epoch 49/50
# 5000/5000 - 7s - loss: 0.0168 - dense_1_loss: 0.0138 - dense_2_loss: 0.0287 - dense_3_loss: 0.0133
# Epoch 50/50
# 5000/5000 - 6s - loss: 0.0166 - dense_1_loss: 0.0138 - dense_2_loss: 0.0279 - dense_3_loss: 0.0132

# %%
### QUANTILEs BOOTSTRAPPING ###
pred_10, pred_50, pred_90 = [], [], []
NN = K.function([model.layers[0].input], 
                [model.layers[-3].output,model.layers[-2].output,model.layers[-1].output])

for i in tqdm.tqdm(range(0,100)):
    # 这里重复试验100次，为了查看10%、50%、90%的点值
    predd = NN([X_test, 0.5])
    pred_10.append(predd[0])
    pred_50.append(predd[1])
    pred_90.append(predd[2])

pred_10 = np.asarray(pred_10)[:,:,0] 
pred_50 = np.asarray(pred_50)[:,:,0]
pred_90 = np.asarray(pred_90)[:,:,0]
# Out:
# 100%|████████████████████████████████████████| 100/100 [05:04<00:00,  3.05s/it]

# %%
print('测试集维度为',X_test.shape,'因此预测值维度为',len(predd[0]),'这里进行100次重复试验，因此预测值结构为',pred_10.shape)
# Out:
# 测试集维度为 (5272, 48, 1) 因此预测值维度为 5272 这里进行100次重复试验，因此预测值结构为 (100, 5272)

# %%
### REVERSE TRANSFORM PREDICTIONS ###
pred_90_m = np.exp(np.quantile(pred_90,0.9,axis=0) + init[5000:])
# 然后按照分位点，提取90%、50%、10%
pred_50_m = np.exp(pred_50.mean(axis=0) + init[5000:])
pred_10_m = np.exp(np.quantile(pred_10,0.1,axis=0) + init[5000:])

# %%
### EVALUATION METRIC ###
mean_squared_log_error(np.exp(y_test + init[5000:]), pred_50_m)
# 调用 MSLE 查看均值情况的误差
# Out:
# 0.07039695556677864

# %%
### PLOT QUANTILE PREDICTIONS ###
plt.figure(figsize=(16,8))
plt.plot(pred_90_m, color='cyan')
plt.plot(pred_50_m, color='blue')
plt.plot(pred_10_m, color='green')

### CROSSOVER CHECK ###
plt.scatter(np.where(np.logical_or(pred_50_m>pred_90_m, pred_50_m<pred_10_m))[0], 
            pred_50_m[np.logical_or(pred_50_m>pred_90_m, pred_50_m<pred_10_m)], c='red', s=50)

# %%
# 这里定义均值在90%以上或者10%以下为异常值
np.where(np.logical_or(pred_50_m>pred_90_m, pred_50_m<pred_10_m))[0]
# Out:
# array([], dtype=int64)

# %%
### PLOT UNCERTAINTY INTERVAL LENGHT WITH REAL DATA ###
plt.figure(figsize=(16,8))
plt.plot(np.exp(y_test + init[5000:]), color='red', alpha=0.4)
# `y_test` 是真实目标，红线体现真实的波动情况。
plt.scatter(range(len(pred_10_m)), pred_90_m - pred_10_m)
# 散点体现预测在10%-90%区间内的波动，体现不确定性，如果越大，说明预测能力越差，这里可以看到y越异常，不确定性越大。

# %% [markdown]
# 总结下来，就是做好时间序列的特征，用滞后项做x，预测三条y的并行序列，最后选用三个序列拟合90%、50%、10%的点，查看哪一个样本，50%的点不在10~90%的范围内，就是异常值。
